# %% [markdown]
# # Synchrony Analysis

# %% [markdown]
# In this notebook, we will take a look at the relationship between different spike synchrony metrics across varying behavioral conditions and presented stimuli. Our dataset has 26 specimens; 24 with VISp and 12 with LGd measurments.

# %%
# imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sys
# %matplotlib nbagg

print('Packages Imported')
# Out:
# Packages Imported

# %%
# initialize paths
PROJECT_PATH = 'G:/Shared drives/visual_encoding'
REPO_PATH = 'C:/Users/User/visual_encoding'
DF_LOC = 'data/synchrony_data'

sys.path.append(REPO_PATH)

# %% [markdown]
# ## Spontaneous

# %% [markdown]
# The first set of data we will look at is obtained from the "spontaneous" experimental time block of the Allen dataset. We will be comparing spike syncrhony metrics between running and stationary states. Let's look at the DataFrame we created for all conditions.

# %%
spontaneous_10 = pd.read_csv(f'{PROJECT_PATH}/{DF_LOC}/[\'VISp\', \'LGd\']_spontaneous_4_10s.csv')
spontaneous_10.head()
# Out:
#    mean_firing_rate  coefficient_of_variation  SPIKE-distance  \
# 0          4.556471                  1.220351        0.360400
# 1          4.437647                  2.142465        0.351913
# 2          5.139604                  2.117519        0.343688
# 3          5.096040                  1.571216        0.349808
# 4          5.496154                  1.147348        0.362530
#
#    SPIKE-synchrony                            correlation coefficient  \
# 0         0.138419  [[ 1.          0.23605715 -0.34099717 ...  0.1...
# 1         0.135415  [[ 1.          0.46354723 -0.35478744 ...     ...
# 2         0.127224  [[ 1.         -0.29134282  0.32496684 ...     ...
# 3         0.133177  [[ 1.         -0.23386623  0.35074943 ... -0.1...
# 4         0.156067  [[ 1.          0.20872575  0.55518783 ...  0.1...
#
#                        epoch       state brain_structure  session_id
# 0  [4732.269295 4742.269295]  stationary            VISp   771160300
# 1  [4682.977695 4692.977695]     running            VISp   771160300
# 2  [4712.867745 4722.867745]  stationary            VISp   767871931
# 3  [4669.730545 4679.730545]     running            VISp   767871931
# 4  [4827.844215 4837.844215]  stationary            VISp   766640955

# %%
from allen_vc.utils import sync_stats
from allen_vc.plts import sync_plot

metrics = ['mean_firing_rate', 'coefficient_of_variation', 'SPIKE-distance', 'SPIKE-synchrony']
sync_plot(spontaneous_10, metrics, 'state');
# Out:
# <img src="data:image/png;base64,..." width="640">
# C:\Users\User\.conda\envs\py37\lib\site-packages\seaborn\categorical.py:3002: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# <img src="data:image/png;base64,..." width="640">
# C:\Users\User\.conda\envs\py37\lib\site-packages\seaborn\categorical.py:3002: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# <img src="data:image/png;base64,..." width="640">
# C:\Users\User\.conda\envs\py37\lib\site-packages\seaborn\categorical.py:3002: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# <img src="data:image/png;base64,..." width="640">
# C:\Users\User\.conda\envs\py37\lib\site-packages\seaborn\categorical.py:3002: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)

# %%
for region in ['VISp', 'LGd']:
    print(f'BRAIN_STRUCTURE: {region}\n\n\n')
    sync_stats(spontaneous_10[spontaneous_10.get('brain_structure')==region], metrics, 'state')
# Out:
# BRAIN_STRUCTURE: VISp
#
#
#
# Metric: mean_firing_rate
#
# State: stationary
# N = 23
# Mean = 5.365788744416592
# Stdev = 1.0228725200588455
#
# State: running
# N = 24
# Mean = 5.191846442342148
# Stdev = 1.0762926696815276
#
# Independent T-Test (All data)
# Ttest_indResult(statistic=0.5552532101785064, pvalue=0.5814713872665598)
#
# Paired T-Test
# Ttest_relResult(statistic=0.7278100462673135, pvalue=0.47440536152086976)
#
#
#
#
# Metric: coefficient_of_variation
#
# State: stationary
# N = 23
# Mean = 1.3817711619725321
# Stdev = 0.4382517298146987
#
# State: running
# N = 24
# Mean = 1.3767153666731635
# Stdev = 0.4091311397184122
#
# Independent T-Test (All data)
# Ttest_indResult(statistic=0.040020162181132884, pvalue=0.9682540837298156)
#
# Paired T-Test
# Ttest_relResult(statistic=0.4277353494552046, pvalue=0.6730016884492412)
#
#
#
#
# Metric: SPIKE-distance
#
# State: stationary
# N = 23
# Mean = 0.35605482678259603
# Stdev = 0.012370233964916369
#
# State: running
# N = 24
# Mean = 0.3578106971422395
# Stdev = 0.012926908409384024
#
# Independent T-Test (All data)
# Ttest_indResult(statistic=-0.46517958512108465, pvalue=0.6440461952895052)
#
# Paired T-Test
# Ttest_relResult(statistic=-0.9883314675412384, pvalue=0.33373642931310465)
#
#
#
#
# Metric: SPIKE-synchrony
#
# State: stationary
# N = 23
# Mean = 0.1459068447961833
# Stdev = 0.018348605483192233
#
# State: running
# N = 24
# Mean = 0.1440407410716605
# Stdev = 0.017753047148727854
#
# Independent T-Test (All data)
# Ttest_indResult(statistic=0.3467448264685768, pvalue=0.7303993155879451)
#
# Paired T-Test
# Ttest_relResult(statistic=0.44145598078328163, pvalue=0.6631913647477388)
#
#
#
#
# BRAIN_STRUCTURE: LGd
#
#
#
# Metric: mean_firing_rate
#
# State: stationary
# N = 11
# Mean = 11.932179118510227
# Stdev = 3.1749215128653985
#
# State: running
# N = 12
# Mean = 12.47567008012021
# Stdev = 5.0418948839025335
#
# Independent T-Test (All data)
# Ttest_indResult(statistic=-0.29256002267913256, pvalue=0.7727295522547282)
#
# Paired T-Test
# Ttest_relResult(statistic=-0.5309098412156413, pvalue=0.6070703138192342)
#
#
#
#
# Metric: coefficient_of_variation
#
# State: stationary
# N = 11
# Mean = 1.0772010376303454
# Stdev = 0.19472815103918573
#
# State: running
# N = 12
# Mean = 0.993180966409417
# Stdev = 0.1312443968857574
#
# Independent T-Test (All data)
# Ttest_indResult(statistic=1.167856109035833, pvalue=0.2559536277911676)
#
# Paired T-Test
# Ttest_relResult(statistic=1.7831383243769454, pvalue=0.10489078748746056)
#
#
#
#
# Metric: SPIKE-distance
#
# State: stationary
# N = 11
# Mean = 0.33605512470612786
# Stdev = 0.02347365507657711
#
# State: running
# N = 12
# Mean = 0.35356876803603754
# Stdev = 0.026213870443582067
#
# Independent T-Test (All data)
# Ttest_indResult(statistic=-1.6074325630141733, pvalue=0.12289189244267543)
#
# Paired T-Test
# Ttest_relResult(statistic=-1.7901827040461344, pvalue=0.10369622684295898)
#
#
#
#
# Metric: SPIKE-synchrony
#
# State: stationary
# N = 11
# Mean = 0.23473745139942068
# Stdev = 0.027937267135741628
#
# State: running
# N = 12
# Mean = 0.20566791903057993
# Stdev = 0.05304806295959081
#
# Independent T-Test (All data)
# Ttest_indResult(statistic=1.5506744618159882, pvalue=0.13592025213345313)
#
# Paired T-Test
# Ttest_relResult(statistic=1.5459975153617276, pvalue=0.15314106611963116)

# %% [markdown]
# Now, let's look at a comparison between the same metrics for epochs of length 30 seconds instead of 10.

# %%
spontaneous_30 = pd.read_csv(f'{PROJECT_PATH}/{DF_LOC}/[\'VISp\', \'LGd\']_spontaneous_4_30s.csv')
spontaneous_30.head()
# Out:
#    mean_firing_rate  coefficient_of_variation  SPIKE-distance  \
# 0          4.857255                  1.598912        0.360336
# 1          4.736471                  1.299670        0.369068
# 2          4.409571                  1.125890        0.376980
# 3          4.835314                  1.145369        0.374007
# 4          5.444231                  1.178586        0.364498
#
#    SPIKE-synchrony                            correlation coefficient  \
# 0         0.142192  [[ 1.          0.37260541  0.31910396 ... -0.0...
# 1         0.154450  [[ 1.          0.54216323  0.03369312 ...  0.2...
# 2         0.121533  [[ 1.         -0.28217653  0.00265346 ...     ...
# 3         0.130002  [[ 1.00000000e+00 -6.71155904e-04  2.89700403e...
# 4         0.150144  [[ 1.          0.10015138  0.17833474 ...  0.1...
#
#                        epoch       state brain_structure  session_id
# 0  [4732.269295 4762.269295]  stationary            VISp   771160300
# 1  [4911.308495 4941.308495]     running            VISp   771160300
# 2  [4461.334945 4491.334945]  stationary            VISp   767871931
# 3  [4845.466545 4875.466545]     running            VISp   767871931
# 4  [4827.844215 4857.844215]  stationary            VISp   766640955

# %%
sync_plot(spontaneous_30, metrics, 'state');
# Out:
# <img src="data:image/png;base64,..." width="640">
# C:\Users\User\.conda\envs\py37\lib\site-packages\seaborn\categorical.py:3002: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# <img src="data:image/png;base64,..." width="640">
# C:\Users\User\.conda\envs\py37\lib\site-packages\seaborn\categorical.py:3002: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# <img src="data:image/png;base64,..." width="640">
# C:\Users\User\.conda\envs\py37\lib\site-packages\seaborn\categorical.py:3002: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# <img src="data:image/png;base64,..." width="640">
# C:\Users\User\.conda\envs\py37\lib\site-packages\seaborn\categorical.py:3002: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)

# %%
for region in ['VISp', 'LGd']:
    print(f'BRAIN_STRUCTURE: {region}\n\n\n')
    sync_stats(spontaneous_30[spontaneous_30.get('brain_structure')==region], metrics, 'state', paired_ttest=True)
# Out:
# BRAIN_STRUCTURE: VISp
#
#
#
# Metric: mean_firing_rate
#
# State: stationary
# N = 21
# Mean = 5.239000072415664
# Stdev = 0.9425298074927313
#
# State: running
# N = 18
# Mean = 5.39048821318145
# Stdev = 0.9860517432175055
#
# Independent T-Test (All data)
# Ttest_indResult(statistic=-0.47708640802385677, pvalue=0.6361065932312095)
#
# Paired T-Test
# Ttest_relResult(statistic=-1.3176400508775619, pvalue=0.20878043706569172)
#
#
#
#
# Metric: coefficient_of_variation
#
# State: stationary
# N = 21
# Mean = 1.3475364984925973
# Stdev = 0.33440240553394096
#
# State: running
# N = 18
# Mean = 1.343926436027009
# Stdev = 0.34080615932052777
#
# Independent T-Test (All data)
# Ttest_indResult(statistic=0.032447888025716604, pvalue=0.9742892841570507)
#
# Paired T-Test
# Ttest_relResult(statistic=-0.24480943185487913, pvalue=0.8101557756518534)
#
#
#
#
# Metric: SPIKE-distance
#
# State: stationary
# N = 21
# Mean = 0.3659903792505269
# Stdev = 0.011935812543695766
#
# State: running
# N = 18
# Mean = 0.3694067444460998
# Stdev = 0.013870675528607003
#
# Independent T-Test (All data)
# Ttest_indResult(statistic=-0.8052586818764674, pvalue=0.4258151846672865)
#
# Paired T-Test
# Ttest_relResult(statistic=-0.6012461749444771, pvalue=0.5572865309834726)
#
#
#
#
# Metric: SPIKE-synchrony
#
# State: stationary
# N = 21
# Mean = 0.14144234502826433
# Stdev = 0.017896881270767516
#
# State: running
# N = 18
# Mean = 0.14200337117715975
# Stdev = 0.016076574309140217
#
# Independent T-Test (All data)
# Ttest_indResult(statistic=-0.09959911448666477, pvalue=0.9212002944379671)
#
# Paired T-Test
# Ttest_relResult(statistic=-1.1322326401226384, pvalue=0.2765570198163796)
#
#
#
#
# BRAIN_STRUCTURE: LGd
#
#
#
# Metric: mean_firing_rate
#
# State: stationary
# N = 9
# Mean = 10.626661032863733
# Stdev = 2.149669123684159
#
# State: running
# N = 11
# Mean = 12.354438359900955
# Stdev = 3.64892601644269
#
# Independent T-Test (All data)
# Ttest_indResult(statistic=-1.189292927231633, pvalue=0.2497769135250721)
#
# Paired T-Test
# Ttest_relResult(statistic=-0.8637194690411258, pvalue=0.4163528810150604)
#
#
#
#
# Metric: coefficient_of_variation
#
# State: stationary
# N = 9
# Mean = 1.031625104101382
# Stdev = 0.07178361182018059
#
# State: running
# N = 11
# Mean = 1.022496539802644
# Stdev = 0.17149063566741332
#
# Independent T-Test (All data)
# Ttest_indResult(statistic=0.14168165004243624, pvalue=0.8889051661885745)
#
# Paired T-Test
# Ttest_relResult(statistic=0.012661465536847705, pvalue=0.9902511857128731)
#
#
#
#
# Metric: SPIKE-distance
#
# State: stationary
# N = 9
# Mean = 0.3505124431109532
# Stdev = 0.016945021062683013
#
# State: running
# N = 11
# Mean = 0.3480133129811167
# Stdev = 0.029203839665088886
#
# Independent T-Test (All data)
# Ttest_indResult(statistic=0.2156544769394229, pvalue=0.8316819055891539)
#
# Paired T-Test
# Ttest_relResult(statistic=0.5982501929337175, pvalue=0.5685165584216825)
#
#
#
#
# Metric: SPIKE-synchrony
#
# State: stationary
# N = 9
# Mean = 0.2189378221630548
# Stdev = 0.040285445610169064
#
# State: running
# N = 11
# Mean = 0.21518447669704163
# Stdev = 0.0403429047636275
#
# Independent T-Test (All data)
# Ttest_indResult(statistic=0.19649592914051445, pvalue=0.8464235111821851)
#
# Paired T-Test
# Ttest_relResult(statistic=-0.8689155927733883, pvalue=0.4136907313491397)

# %% [markdown]
# # Natural Movie

# %% [markdown]
# Additionally, the mice were subjected to the repetition of 30 second movies 60 times throughout each session. Let's look at how this data compares to the spontaneous data and its relationship with behavioral state.

# %%
import pandas as pd
import numpy as np
import sys

# initialize paths
PROJECT_PATH = 'G:/Shared drives/visual_encoding'
REPO_PATH = 'C:/Users/User/visual_encoding'
DF_LOC = 'data/synchrony_data'

sys.path.append(REPO_PATH)
from allen_vc.plts import sync_plot
from allen_vc.utils import sync_stats

# %%
natural_movie = pd.read_csv(f'{PROJECT_PATH}/{DF_LOC}/[\'VISp\', \'LGd\']_natural_movie_one_more_repeats_30s.csv')
natural_movie = natural_movie.sort_values(by=['session_id', 'brain_structure','state']).reset_index(drop=True)

bool_array = np.load(f'{PROJECT_PATH}/data/behavior/running/epoch_times/natural_movie_one_running_bool.npz', allow_pickle=True)
counts = natural_movie.get('session_id').value_counts()

running_bool = []
for i in range(len(counts)):
    for x in range(counts.iloc[i]//60):
        running_bool.extend(bool_array[str(counts.index[i])])

natural_movie = natural_movie.assign(running=running_bool)
metrics = ['mean_firing_rate', 'coefficient_of_variation', 'SPIKE-distance', 'SPIKE-synchrony']
natural_movie
# Out:
#       mean_firing_rate  coefficient_of_variation  SPIKE-distance  \
# 0             9.927227                  1.051236        0.339494
# 1             9.348748                  1.107313        0.339049
# 2             8.559517                  1.113933        0.335621
# 3             8.422339                  1.176059        0.334136
# 4             9.173897                  1.108061        0.338537
# ...                ...                       ...             ...
# 2095         11.875457                  1.122218        0.350335
# 2096         10.036999                  1.135040        0.350535
# 2097          7.648301                  1.836224        0.338283
# 2098          7.358552                  2.204570        0.338817
# 2099          7.352554                  1.962660        0.341942
#
#       SPIKE-synchrony                            correlation coefficient  \
# 0            0.168037  [[ 1.         -0.08209537 -0.07011903 ... -0.0...
# 1            0.159469  [[ 1.          0.1632112  -0.40520209 ...  0.1...
# 2            0.153470  [[ 1.         -0.10177533  0.19547559 ...  0.0...
# 3            0.152521  [[ 1.          0.01761615  0.26024454 ...  0.1...
# 4            0.162200  [[ 1.          0.23984402  0.01932491 ... -0.1...
# ...               ...                                                ...
# 2095         0.237185  [[ 1.          0.10384419 -0.31875367 ...  0.0...
# 2096         0.225961  [[ 1.          0.59189933 -0.05907816 ...  0.2...
# 2097         0.204963  [[ 1.          0.07445706 -0.14772258 ... -0.0...
# 2098         0.194767  [[ 1.          0.00219292 -0.22948865 ...  0.1...
# 2099         0.197555  [[ 1.          0.11664363  0.14521311 ...  0.1...
#
#                               epoch  state brain_structure  session_id running
# 0     [2297.21288415 2327.23796415]      0             LGd   766640955    True
# 1     [2327.23796415 2357.26309415]      1             LGd   766640955    True
# 2     [2357.26309415 2387.28815415]      2             LGd   766640955    True
# 3     [2387.28815415 2417.31325415]      3             LGd   766640955    True
# 4     [2417.31325415 2447.33837415]      4             LGd   766640955    True
# ...                             ...    ...             ...         ...     ...
# 2095  [8145.35491995 8175.37986995]     55            VISp   847657808   False
# 2096  [8175.37986995 8205.40477995]     56            VISp   847657808   False
# 2097  [8205.40477995 8235.42974995]     57            VISp   847657808   False
# 2098  [8235.42974995 8265.45467995]     58            VISp   847657808   False
# 2099  [8265.45467995 8295.47961995]     59            VISp   847657808   False
#
# [2100 rows x 10 columns]

# %%
natural_movie.get('running').unique()[1]

# %%
natural_movie[(natural_movie.get('running')!=True) & (natural_movie.get('running')!=False)]
# Out:
#       mean_firing_rate  coefficient_of_variation  SPIKE-distance  \
# 13            8.542426                  1.170169        0.330965
# 14            8.446883                  1.146143        0.335472
# 30           15.498447                  1.020938        0.335136
# 34           14.227575                  1.032977        0.333320
# 40           12.439162                  1.047462        0.331442
# ...                ...                       ...             ...
# 2072          7.968051                  1.668087        0.343368
# 2077          7.542401                  2.234494        0.338818
# 2078          8.073952                  2.007677        0.341595
# 2080          8.309090                  1.602730        0.344733
# 2082          8.372370                  1.614601        0.350105
#
#       SPIKE-synchrony                            correlation coefficient  \
# 13           0.157583  [[ 1.          0.21798521  0.44526604 ...  0.2...
# 14           0.153849  [[ 1.          0.16915562  0.35815295 ...  0.0...
# 30           0.211386  [[ 1.         -0.02825945  0.34237364 ...  0.0...
# 34           0.221562  [[ 1.         -0.04275519  0.16203413 ...  0.0...
# 40           0.211733  [[ 1.         -0.12421596  0.24645748 ...  0.3...
# ...               ...                                                ...
# 2072         0.202396  [[ 1.          0.19797345 -0.32179826 ... -0.2...
# 2077         0.192611  [[ 1.          0.2313949   0.04978317 ...  0.4...
# 2078         0.195188  [[ 1.          0.19192906  0.30172091 ...  0.3...
# 2080         0.202410  [[ 1.          0.046575   -0.02213503 ...  0.0...
# 2082         0.200574  [[ 1.          0.34290449  0.0307747  ...  0.1...
#
#                               epoch  state brain_structure  session_id running
# 13    [2687.53907415 2717.56413415]     13             LGd   766640955    None
# 14    [2717.56413415 2747.58922415]     14             LGd   766640955    None
# 30    [7401.47791415 7431.50299415]     30             LGd   766640955    None
# 34    [7521.57827415 7551.60336415]     34             LGd   766640955    None
# 40    [7701.72882415 7731.75390415]     40             LGd   766640955    None
# ...                             ...    ...             ...         ...     ...
# 2072  [7454.78124995 7484.80615995]     32            VISp   847657808    None
# 2077  [7604.90593995 7634.93085995]     37            VISp   847657808    None
# 2078  [7634.93085995 7664.95580995]     38            VISp   847657808    None
# 2080  [7694.98075995 7725.00570995]     40            VISp   847657808    None
# 2082  [7755.03063995 7785.05558995]     42            VISp   847657808    None
#
# [459 rows x 10 columns]

# %%
# what about none?

sync_plot(natural_movie, metrics, 'running');
# Out:
# C:\Users\User\.conda\envs\py37\lib\site-packages\seaborn\categorical.py:3002: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# C:\Users\User\.conda\envs\py37\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 10.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\User\.conda\envs\py37\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 48.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\User\.conda\envs\py37\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 23.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\User\.conda\envs\py37\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 81.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\User\.conda\envs\py37\lib\site-packages\seaborn\categorical.py:3002: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# C:\Users\User\.conda\envs\py37\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 46.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\User\.conda\envs\py37\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 79.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\User\.conda\envs\py37\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 13.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\User\.conda\envs\py37\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 72.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\User\.conda\envs\py37\lib\site-packages\seaborn\categorical.py:3002: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# C:\Users\User\.conda\envs\py37\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 29.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\User\.conda\envs\py37\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 59.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\User\.conda\envs\py37\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 24.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\User\.conda\envs\py37\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 79.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\User\.conda\envs\py37\lib\site-packages\seaborn\categorical.py:3002: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# C:\Users\User\.conda\envs\py37\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 44.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\User\.conda\envs\py37\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 24.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\User\.conda\envs\py37\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 77.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
# don't include paired t-test

for region in ['VISp', 'LGd']:
    print(f'BRAIN_STRUCTURE: {region}\n\n\n')
    sync_stats(natural_movie[natural_movie.get('brain_structure')==region], metrics, 'running')
# Out:
# BRAIN_STRUCTURE: VISp
#
#
#
# Metric: mean_firing_rate
#
# State: True
# N = 23
# Mean = 6.746375535511456
# Stdev = 2.181974454798892
#
# State: False
# N = 23
# Mean = 7.531525400191027
# Stdev = 2.0321831523120086
#
# Independent T-Test (All data)
# Ttest_indResult(statistic=-1.2350767519787818, pvalue=0.22335660793943904)
#
#
#
#
#
# Metric: coefficient_of_variation
#
# State: True
# N = 23
# Mean = 1.5357032253795335
# Stdev = 0.40463647711294454
#
# State: False
# N = 23
# Mean = 1.5294515716054473
# Stdev = 0.43785079359423557
#
# Independent T-Test (All data)
# Ttest_indResult(statistic=0.04918364001595464, pvalue=0.9609955357989136)
#
#
#
#
#
# Metric: SPIKE-distance
#
# State: True
# N = 23
# Mean = 0.36200745813509
# Stdev = 0.010159950162603744
#
# State: False
# N = 23
# Mean = 0.36345874559694374
# Stdev = 0.008327566469570558
#
# Independent T-Test (All data)
# Ttest_indResult(statistic=-0.5181773448705663, pvalue=0.6069305713751838)
#
#
#
#
#
# Metric: SPIKE-synchrony
#
# State: True
# N = 23
# Mean = 0.1411226321983649
# Stdev = 0.015818625926570174
#
# State: False
# N = 23
# Mean = 0.14556151348039068
# Stdev = 0.01711265419448987
#
# Independent T-Test (All data)
# Ttest_indResult(statistic=-0.89342113193973, pvalue=0.37649246007075143)
#
#
#
#
#
# BRAIN_STRUCTURE: LGd
#
#
#
# Metric: mean_firing_rate
#
# State: True
# N = 12
# Mean = 13.109538644009461
# Stdev = 4.4947383026987096
#
# State: False
# N = 12
# Mean = 13.860549313452028
# Stdev = 5.095932833105109
#
# Independent T-Test (All data)
# Ttest_indResult(statistic=-0.3665699416493109, pvalue=0.7174417778287026)
#
#
#
#
#
# Metric: coefficient_of_variation
#
# State: True
# N = 12
# Mean = 1.0312350607850178
# Stdev = 0.11781012011510779
#
# State: False
# N = 12
# Mean = 1.0467812693783936
# Stdev = 0.15424666790283292
#
# Independent T-Test (All data)
# Ttest_indResult(statistic=-0.2656536369239352, pvalue=0.7929795381743435)
#
#
#
#
#
# Metric: SPIKE-distance
#
# State: True
# N = 12
# Mean = 0.34228511886496743
# Stdev = 0.013167232782218074
#
# State: False
# N = 12
# Mean = 0.3407828047127172
# Stdev = 0.013256792913085165
#
# Independent T-Test (All data)
# Ttest_indResult(statistic=0.2666678266120188, pvalue=0.7922085116311903)
#
#
#
#
#
# Metric: SPIKE-synchrony
#
# State: True
# N = 12
# Mean = 0.2043003182254174
# Stdev = 0.049022482819581055
#
# State: False
# N = 12
# Mean = 0.21350499383342483
# Stdev = 0.05582907960467009
#
# Independent T-Test (All data)
# Ttest_indResult(statistic=-0.41089584803160784, pvalue=0.6851237007117008)
